# %%
import torch, dgl, os
import numpy as np
import pandas as pd

from glob import glob
from time import time
from datetime import datetime

from dgl.data.utils import Subset
from dgl.dataloading import GraphDataLoader

from sklearn.model_selection import KFold

from data.dataset import MSPDataset

from model.model import MetabolicStabilityPrediction, MSP_MoE

from train.utils import *
from train.train import *
from train.early_stop import EarlyStopping
from train.scheduler import CosineAnnealingWarmUpRestarts

# %%
TORCH = format_pytorch_version(torch.__version__)
CUDA = format_cuda_version(torch.version.cuda)
DGL = format_dgl_version(dgl.__version__)
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"[INFO] DEVICE: {device}, CUDA version: {CUDA}, TORCH version: {TORCH}, DGL version: {DGL}")
# Out:
# [INFO] DEVICE: cuda, CUDA version: cu117, TORCH version: 2.0.1, DGL version: 1.1.1+cu117

# %%
hyperparameter = { 'batch_size':64, 'num_layers': 8, 'out_size': 128, 'node_dim': 62, 'pose_dim': 20, 'edge_dim': 13, 
                  'lr_min': 1e-4, 'lr_max': 1e-2, 'T_0': 20, 'T_mult':1, 'T_up':5, 'T_gamma':0.9, 'dropout_ratio':0.15,
                  'model_type': 'GatedGCNLSPE_MoE', 'loss_function': 'BCE', 'seed':42 }

# %%
def cross_validation_training( train_data_paths, hyperparameter, device="cuda" ):
    batch_size = hyperparameter.get('batch_size', 64)
     
    num_layers = hyperparameter.get( 'num_layers', 8 )
    out_size   = hyperparameter.get( 'out_size', 256 )
    pose_dim   = hyperparameter.get( 'pose_dim', 20 )
    node_dim   = hyperparameter.get( 'node_dim', 57 )
    edge_dim   = hyperparameter.get( 'edge_dim', 13 )
    dropout_ratio  = hyperparameter.get( 'dropout_ration', 0.15 )
    
    lr_min  = hyperparameter.get( 'lr_min',  1e-6 )
    lr_max  = hyperparameter.get( 'lr_max',  1e-2 )
    T_0     = hyperparameter.get( 'T_0',     20 )
    T_mult  = hyperparameter.get( 'T_mult',  1 )
    T_up    = hyperparameter.get( 'T_up',    5 )
    T_gamma = hyperparameter.get( 'T_gamma', 0.8 )
    seed = hyperparameter.get( 'seed', 42 )
    
    model_type    = hyperparameter.get( 'model_type', 'GatedGCN')
    loss_function = hyperparameter.get( 'loss_function', 'MSE' )

    set_random_seed(seed)
    
    g = torch.Generator()
    g.manual_seed(seed)
    
    n_splits = 5
    kf = KFold( n_splits=n_splits, shuffle=True, random_state=seed )

    train = MSPDataset( train_data_paths, pos_enc_dim=pose_dim )

    oof_preds = np.zeros((len(train_data_paths)))
    oof_trues = np.zeros((len(train_data_paths)))

    LOSS = { idx: [] for idx in range(n_splits) }

    for num, (train_id, valid_id) in enumerate( kf.split( train ) ):
        model_path = f'./save/{loss_function}_{model_type}_nl{num_layers}_od{out_size}_pd{pose_dim}_bs{batch_size}_lmax{lr_max}_lmin{lr_min}_seed{seed}'

        if not os.path.isdir( model_path ):
            os.makedirs(model_path)
        else:
            print( 'already made' )

        dt = datetime.now()
        dt = f'{model_path}/early_stop_{dt.date()}_{dt.hour:02d}-{dt.minute:02d}-{dt.second:02d}_{num}fold.pth'

        print(f"# # # # # # # # # # Start {num}-fold cross validation # # # # # # # # # # ")
        train_data = Subset( train, train_id )
        valid_data = Subset( train, valid_id )
    
        train_loader = GraphDataLoader(train_data, batch_size=batch_size, shuffle=True,  drop_last=False, generator=g)
        valid_loader = GraphDataLoader(valid_data, batch_size=batch_size, shuffle=False, drop_last=False, generator=g )

        model = MetabolicStabilityPrediction(node_dim, out_size, edge_dim, pose_dim, 1024, num_layers=num_layers).to(device)
        # model = MSP_MoE( node_dim, edge_dim, pose_dim, out_size, num_layers, 1024, num_experts=5).to(device)

        stopper = EarlyStopping( patience=100, mode="higher", metric="rmse", filename=dt)

        optimizer = torch.optim.AdamW(model.parameters(), lr=lr_min)
        scheduler = CosineAnnealingWarmUpRestarts( optimizer, T_0=T_0, T_mult=T_mult, eta_max=lr_max, T_up=T_up, gamma=T_gamma )

        each_fold_loss = { "TRAIN":[], "VALID":[] }
        for epoch in range(1, 10001):
            start = time()
            lr = optimizer.param_groups[0]["lr"]

            train_loss = train_model(model, train_loader, optimizer, scheduler, device=device)
            valid_loss, valid_pred, valid_true, valid_name = valid_model( model, valid_loader, device=device ) ## 1 fold 

            each_fold_loss["TRAIN"].append( train_loss )
            each_fold_loss["VALID"].append( valid_loss )
            
            print( f"\n[ INFO ] {num+1} Fold, Epoch: {epoch:04d}, Lr: {lr:.5f}, Time: {time() - start:.2f}, Train Loss: {train_loss:.3f}, Valid Loss: {valid_loss:.3f}" )
            
            results = analysis(valid_true, valid_pred)
            analysis_table(results)        
            
            early_stop = stopper.step(results["ROC_AUC"], model)
            if early_stop:
                model.load_state_dict(torch.load(dt)['model_state_dict'])
    
                valid_loss, valid_pred, valid_true, valid_name = valid_model( model, valid_loader, device=device ) ## 1 fold 
    
                oof_preds[valid_id] = valid_pred
                oof_trues[valid_id] = valid_true
                break
                
        LOSS[num].append( each_fold_loss )
        
    return oof_preds, oof_trues, model_path, LOSS

# %%
random_seeds = [42, 189, 2494, 4592, 22232, 49492, 89982, 100294, 199606, 202310]
random_seeds = [42]
random_seeds
# Out:
# [42]

# %%
oof_preds_list = []
oof_trues_list = []
loss_list = []
for seed in random_seeds:
    hyperparameter['seed'] = seed
    
    print( f'seed: {seed} start' )
    oof_preds, oof_trues, model_path, LOSS = cross_validation_training( glob("./data/train/*"), hyperparameter)
    print( f'seed: {seed} done' )
    
    oof_preds_list.append( oof_preds )
    oof_trues_list.append( oof_trues )
    loss_list.append( LOSS )
# Out:
# 42 start
# [INFO] RANDOM, DGL, NUMPY and TORCH random seed is set 42.
# already made
# # # # # # # # # # # Start 0-fold cross validation # # # # # # # # # #
# For metric rmse, the lower the better.
#
# [ INFO ] 1 Fold, Epoch: 0001, Lr: 0.00010, Time: 1.60, Train Loss: 0.689, Valid Loss: 0.736
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.540 | 0.189 |       0.758        |    0.499    |     0.224     | 0.915 | 0.345 |  0.628  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
#
# [ INFO ] 1 Fold, Epoch: 0002, Lr: 0.00208, Time: 1.56, Train Loss: 0.650, Valid Loss: 0.742
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.566 | 0.225 |       0.762        |    0.515    |     0.289     | 0.893 | 0.419 |  0.639  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
#
# [ INFO ] 1 Fold, Epoch: 0003, Lr: 0.00406, Time: 1.48, Train Loss: 0.631, Valid Loss: 0.654
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.635 | 0.266 |       0.615        |    0.698    |     0.870     | 0.357 | 0.721 |  0.657  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
#
# [ INFO ] 1 Fold, Epoch: 0004, Lr: 0.00604, Time: 1.52, Train Loss: 0.637, Valid Loss: 0.700
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.567 | 0.228 |       0.764        |    0.516    |     0.292     | 0.893 | 0.422 |  0.640  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 1 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0005, Lr: 0.00802, Time: 1.51, Train Loss: 0.624, Valid Loss: 0.641
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.655 | 0.311 |       0.697        |    0.613    |     0.643     | 0.669 | 0.669 |  0.655  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 2 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0006, Lr: 0.01000, Time: 1.51, Train Loss: 0.635, Valid Loss: 0.629
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.630 | 0.266 |       0.683        |    0.582    |     0.590     | 0.676 | 0.633 |  0.633  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 3 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0007, Lr: 0.00989, Time: 1.53, Train Loss: 0.622, Valid Loss: 0.614
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.670 | 0.348 |       0.728        |    0.619    |     0.624     | 0.724 | 0.672 |  0.674  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
#
# [ INFO ] 1 Fold, Epoch: 0008, Lr: 0.00957, Time: 1.59, Train Loss: 0.616, Valid Loss: 0.686
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.604 | 0.281 |       0.774        |    0.543    |     0.382     | 0.868 | 0.511 |  0.658  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 1 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0009, Lr: 0.00905, Time: 1.58, Train Loss: 0.609, Valid Loss: 0.616
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.653 | 0.297 |       0.663        |    0.639    |     0.733     | 0.559 | 0.696 |  0.651  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 2 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0010, Lr: 0.00836, Time: 1.55, Train Loss: 0.610, Valid Loss: 0.613
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.658 | 0.323 |       0.712        |    0.610    |     0.621     | 0.702 | 0.663 |  0.661  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 3 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0011, Lr: 0.00753, Time: 1.56, Train Loss: 0.611, Valid Loss: 0.623
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.670 | 0.337 |       0.649        |    0.721    |     0.851     | 0.456 | 0.737 |  0.685  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
#
# [ INFO ] 1 Fold, Epoch: 0012, Lr: 0.00658, Time: 1.53, Train Loss: 0.599, Valid Loss: 0.650
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.636 | 0.325 |       0.776        |    0.570    |     0.463     | 0.842 | 0.580 |  0.673  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 1 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0013, Lr: 0.00557, Time: 1.48, Train Loss: 0.595, Valid Loss: 0.672
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.603 | 0.235 |       0.694        |    0.548    |     0.478     | 0.750 | 0.566 |  0.621  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 2 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0014, Lr: 0.00453, Time: 1.50, Train Loss: 0.589, Valid Loss: 0.597
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.699 | 0.390 |       0.708        |    0.685    |     0.755     | 0.632 | 0.731 |  0.697  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
#
# [ INFO ] 1 Fold, Epoch: 0015, Lr: 0.00352, Time: 1.51, Train Loss: 0.587, Valid Loss: 0.654
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.608 | 0.201 |       0.619        |    0.588    |     0.717     | 0.478 | 0.665 |  0.604  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 1 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0016, Lr: 0.00258, Time: 1.43, Train Loss: 0.575, Valid Loss: 0.600
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.684 | 0.370 |       0.729        |    0.639    |     0.661     | 0.710 | 0.694 |  0.684  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 2 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0017, Lr: 0.00174, Time: 1.49, Train Loss: 0.562, Valid Loss: 0.597
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.682 | 0.355 |       0.680        |    0.684    |     0.780     | 0.566 | 0.726 |  0.682  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 3 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0018, Lr: 0.00105, Time: 1.52, Train Loss: 0.550, Valid Loss: 0.594
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.692 | 0.381 |       0.721        |    0.659    |     0.705     | 0.676 | 0.713 |  0.690  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 4 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0019, Lr: 0.00053, Time: 1.55, Train Loss: 0.543, Valid Loss: 0.605
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.689 | 0.391 |       0.760        |    0.631    |     0.621     | 0.768 | 0.684 |  0.696  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 5 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0020, Lr: 0.00021, Time: 1.53, Train Loss: 0.539, Valid Loss: 0.598
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.699 | 0.404 |       0.754        |    0.649    |     0.658     | 0.746 | 0.703 |  0.702  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
#
# [ INFO ] 1 Fold, Epoch: 0021, Lr: 0.00010, Time: 1.49, Train Loss: 0.541, Valid Loss: 0.598
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.694 | 0.393 |       0.748        |    0.644    |     0.655     | 0.739 | 0.699 |  0.696  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 1 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0022, Lr: 0.00188, Time: 1.46, Train Loss: 0.546, Valid Loss: 0.596
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.697 | 0.387 |       0.710        |    0.680    |     0.745     | 0.640 | 0.727 |  0.695  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 2 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0023, Lr: 0.00366, Time: 1.50, Train Loss: 0.563, Valid Loss: 0.685
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.630 | 0.250 |       0.617        |    0.665    |     0.835     | 0.386 | 0.710 |  0.641  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 3 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0024, Lr: 0.00544, Time: 1.53, Train Loss: 0.572, Valid Loss: 0.782
# +-------+--------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC   | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+--------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.488 | -0.039 |       0.526        |    0.435    |     0.568     | 0.393 | 0.546 |  0.480  |
# +-------+--------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 4 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0025, Lr: 0.00722, Time: 1.52, Train Loss: 0.583, Valid Loss: 0.632
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.670 | 0.350 |       0.733        |    0.617    |     0.615     | 0.735 | 0.669 |  0.675  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 5 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0026, Lr: 0.00900, Time: 1.51, Train Loss: 0.580, Valid Loss: 0.607
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.682 | 0.355 |       0.685        |    0.677    |     0.764     | 0.585 | 0.722 |  0.681  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 6 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0027, Lr: 0.00890, Time: 1.43, Train Loss: 0.583, Valid Loss: 0.690
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.613 | 0.230 |       0.592        |    0.719    |     0.916     | 0.254 | 0.720 |  0.656  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 7 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0028, Lr: 0.00862, Time: 1.55, Train Loss: 0.585, Valid Loss: 0.607
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.675 | 0.346 |       0.701        |    0.645    |     0.699     | 0.647 | 0.700 |  0.673  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 8 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0029, Lr: 0.00815, Time: 1.55, Train Loss: 0.563, Valid Loss: 0.609
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.670 | 0.336 |       0.698        |    0.638    |     0.689     | 0.647 | 0.694 |  0.668  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 9 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0030, Lr: 0.00753, Time: 1.48, Train Loss: 0.565, Valid Loss: 0.657
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.670 | 0.334 |       0.692        |    0.643    |     0.705     | 0.629 | 0.698 |  0.667  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 10 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0031, Lr: 0.00678, Time: 1.48, Train Loss: 0.568, Valid Loss: 0.610
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.680 | 0.375 |       0.754        |    0.623    |     0.609     | 0.765 | 0.674 |  0.688  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 11 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0032, Lr: 0.00593, Time: 1.46, Train Loss: 0.558, Valid Loss: 0.598
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.673 | 0.338 |       0.680        |    0.664    |     0.752     | 0.581 | 0.714 |  0.672  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 12 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0033, Lr: 0.00502, Time: 1.49, Train Loss: 0.547, Valid Loss: 0.599
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.695 | 0.396 |       0.747        |    0.647    |     0.661     | 0.735 | 0.702 |  0.697  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 13 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0034, Lr: 0.00408, Time: 1.45, Train Loss: 0.541, Valid Loss: 0.892
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.542 | 0.151 |       0.676        |    0.500    |     0.298     | 0.831 | 0.414 |  0.588  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 14 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0035, Lr: 0.00317, Time: 1.47, Train Loss: 0.534, Valid Loss: 0.601
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.692 | 0.376 |       0.700        |    0.680    |     0.755     | 0.618 | 0.726 |  0.690  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 15 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0036, Lr: 0.00233, Time: 1.46, Train Loss: 0.522, Valid Loss: 0.604
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.687 | 0.366 |       0.697        |    0.673    |     0.748     | 0.614 | 0.722 |  0.685  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 16 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0037, Lr: 0.00157, Time: 1.45, Train Loss: 0.497, Valid Loss: 0.611
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.692 | 0.385 |       0.732        |    0.651    |     0.680     | 0.706 | 0.705 |  0.692  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 17 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0038, Lr: 0.00095, Time: 1.50, Train Loss: 0.501, Valid Loss: 0.607
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.677 | 0.350 |       0.706        |    0.644    |     0.693     | 0.658 | 0.699 |  0.675  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 18 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0039, Lr: 0.00048, Time: 1.41, Train Loss: 0.495, Valid Loss: 0.608
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.672 | 0.344 |       0.712        |    0.631    |     0.661     | 0.684 | 0.686 |  0.671  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 19 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0040, Lr: 0.00020, Time: 1.46, Train Loss: 0.485, Valid Loss: 0.619
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.692 | 0.392 |       0.751        |    0.640    |     0.646     | 0.746 | 0.694 |  0.696  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 20 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0041, Lr: 0.00010, Time: 1.45, Train Loss: 0.483, Valid Loss: 0.615
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.694 | 0.393 |       0.748        |    0.644    |     0.655     | 0.739 | 0.699 |  0.696  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 21 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0042, Lr: 0.00170, Time: 1.45, Train Loss: 0.494, Valid Loss: 0.639
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.680 | 0.375 |       0.754        |    0.623    |     0.609     | 0.765 | 0.674 |  0.688  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 22 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0043, Lr: 0.00330, Time: 1.41, Train Loss: 0.516, Valid Loss: 0.612
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.677 | 0.346 |       0.692        |    0.656    |     0.727     | 0.618 | 0.709 |  0.674  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 23 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0044, Lr: 0.00490, Time: 1.41, Train Loss: 0.519, Valid Loss: 0.655
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.650 | 0.294 |       0.674        |    0.620    |     0.686     | 0.607 | 0.680 |  0.647  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 24 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0045, Lr: 0.00650, Time: 1.45, Train Loss: 0.527, Valid Loss: 0.649
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.618 | 0.223 |       0.630        |    0.598    |     0.714     | 0.504 | 0.670 |  0.614  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 25 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0046, Lr: 0.00810, Time: 1.47, Train Loss: 0.548, Valid Loss: 0.632
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.645 | 0.280 |       0.635        |    0.667    |     0.811     | 0.449 | 0.712 |  0.651  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 26 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0047, Lr: 0.00801, Time: 1.49, Train Loss: 0.539, Valid Loss: 0.710
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.603 | 0.205 |       0.585        |    0.700    |     0.916     | 0.232 | 0.714 |  0.643  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 27 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0048, Lr: 0.00775, Time: 1.41, Train Loss: 0.539, Valid Loss: 0.621
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.668 | 0.334 |       0.701        |    0.633    |     0.677     | 0.658 | 0.689 |  0.667  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 28 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0049, Lr: 0.00734, Time: 1.46, Train Loss: 0.539, Valid Loss: 0.628
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.694 | 0.397 |       0.757        |    0.640    |     0.640     | 0.757 | 0.694 |  0.699  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 29 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0050, Lr: 0.00678, Time: 1.46, Train Loss: 0.526, Valid Loss: 0.642
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.678 | 0.378 |       0.765        |    0.617    |     0.587     | 0.787 | 0.664 |  0.691  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 30 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0051, Lr: 0.00610, Time: 1.55, Train Loss: 0.515, Valid Loss: 0.622
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.687 | 0.384 |       0.752        |    0.633    |     0.630     | 0.754 | 0.686 |  0.692  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 31 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0052, Lr: 0.00534, Time: 1.43, Train Loss: 0.507, Valid Loss: 0.778
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.603 | 0.188 |       0.603        |    0.601    |     0.780     | 0.393 | 0.680 |  0.602  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 32 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0053, Lr: 0.00452, Time: 1.44, Train Loss: 0.531, Valid Loss: 0.597
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.705 | 0.411 |       0.744        |    0.666    |     0.696     | 0.717 | 0.719 |  0.705  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
#
# [ INFO ] 1 Fold, Epoch: 0054, Lr: 0.00368, Time: 1.44, Train Loss: 0.496, Valid Loss: 0.643
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.673 | 0.353 |       0.729        |    0.624    |     0.634     | 0.721 | 0.678 |  0.676  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 1 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0055, Lr: 0.00286, Time: 1.50, Train Loss: 0.484, Valid Loss: 0.645
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.675 | 0.349 |       0.710        |    0.638    |     0.677     | 0.673 | 0.693 |  0.674  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 2 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0056, Lr: 0.00210, Time: 1.49, Train Loss: 0.472, Valid Loss: 0.642
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.680 | 0.363 |       0.726        |    0.636    |     0.658     | 0.706 | 0.691 |  0.681  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 3 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0057, Lr: 0.00142, Time: 1.46, Train Loss: 0.461, Valid Loss: 0.625
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.680 | 0.353 |       0.692        |    0.664    |     0.739     | 0.610 | 0.715 |  0.678  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 4 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0058, Lr: 0.00086, Time: 1.47, Train Loss: 0.436, Valid Loss: 0.670
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.678 | 0.367 |       0.742        |    0.625    |     0.624     | 0.743 | 0.678 |  0.684  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 5 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0059, Lr: 0.00045, Time: 1.53, Train Loss: 0.437, Valid Loss: 0.651
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.682 | 0.367 |       0.729        |    0.637    |     0.658     | 0.710 | 0.692 |  0.683  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 6 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0060, Lr: 0.00019, Time: 1.54, Train Loss: 0.424, Valid Loss: 0.657
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.684 | 0.370 |       0.731        |    0.638    |     0.658     | 0.713 | 0.693 |  0.685  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 7 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0061, Lr: 0.00010, Time: 1.49, Train Loss: 0.419, Valid Loss: 0.651
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.687 | 0.375 |       0.728        |    0.645    |     0.674     | 0.702 | 0.700 |  0.687  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 8 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0062, Lr: 0.00154, Time: 1.49, Train Loss: 0.440, Valid Loss: 0.658
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.665 | 0.327 |       0.696        |    0.630    |     0.677     | 0.651 | 0.687 |  0.663  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 9 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0063, Lr: 0.00298, Time: 1.50, Train Loss: 0.446, Valid Loss: 0.664
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.672 | 0.338 |       0.695        |    0.643    |     0.702     | 0.636 | 0.699 |  0.669  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 10 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0064, Lr: 0.00441, Time: 1.50, Train Loss: 0.475, Valid Loss: 0.641
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.704 | 0.418 |       0.770        |    0.648    |     0.646     | 0.772 | 0.703 |  0.709  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
#
# [ INFO ] 1 Fold, Epoch: 0065, Lr: 0.00585, Time: 1.46, Train Loss: 0.492, Valid Loss: 0.650
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.678 | 0.351 |       0.699        |    0.653    |     0.714     | 0.636 | 0.707 |  0.676  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 1 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0066, Lr: 0.00729, Time: 1.40, Train Loss: 0.514, Valid Loss: 0.676
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.662 | 0.349 |       0.755        |    0.599    |     0.556     | 0.787 | 0.640 |  0.677  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 2 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0067, Lr: 0.00721, Time: 1.42, Train Loss: 0.509, Valid Loss: 0.591
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.684 | 0.359 |       0.693        |    0.671    |     0.748     | 0.607 | 0.719 |  0.682  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 3 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0068, Lr: 0.00698, Time: 1.42, Train Loss: 0.491, Valid Loss: 0.692
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.638 | 0.315 |       0.754        |    0.574    |     0.494     | 0.809 | 0.597 |  0.664  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 4 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0069, Lr: 0.00660, Time: 1.46, Train Loss: 0.473, Valid Loss: 0.680
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.665 | 0.341 |       0.730        |    0.612    |     0.606     | 0.735 | 0.662 |  0.671  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 5 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0070, Lr: 0.00610, Time: 1.49, Train Loss: 0.473, Valid Loss: 0.783
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.636 | 0.316 |       0.760        |    0.572    |     0.481     | 0.820 | 0.589 |  0.666  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 6 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0071, Lr: 0.00549, Time: 1.46, Train Loss: 0.485, Valid Loss: 0.662
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.662 | 0.321 |       0.695        |    0.625    |     0.671     | 0.651 | 0.682 |  0.660  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 7 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0072, Lr: 0.00481, Time: 1.50, Train Loss: 0.457, Valid Loss: 0.658
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.667 | 0.324 |       0.667        |    0.667    |     0.770     | 0.544 | 0.715 |  0.667  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 8 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0073, Lr: 0.00407, Time: 1.46, Train Loss: 0.451, Valid Loss: 0.693
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.665 | 0.361 |       0.771        |    0.599    |     0.543     | 0.809 | 0.638 |  0.685  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 9 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0074, Lr: 0.00332, Time: 1.46, Train Loss: 0.423, Valid Loss: 0.681
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.687 | 0.374 |       0.727        |    0.646    |     0.677     | 0.699 | 0.701 |  0.686  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 10 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0075, Lr: 0.00258, Time: 1.44, Train Loss: 0.408, Valid Loss: 0.708
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.672 | 0.354 |       0.736        |    0.618    |     0.615     | 0.739 | 0.670 |  0.677  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 11 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0076, Lr: 0.00190, Time: 1.48, Train Loss: 0.378, Valid Loss: 0.748
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.673 | 0.355 |       0.732        |    0.623    |     0.627     | 0.728 | 0.676 |  0.677  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 12 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0077, Lr: 0.00129, Time: 1.55, Train Loss: 0.351, Valid Loss: 0.779
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.673 | 0.347 |       0.713        |    0.633    |     0.665     | 0.684 | 0.688 |  0.673  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 13 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0078, Lr: 0.00079, Time: 1.53, Train Loss: 0.351, Valid Loss: 0.769
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.682 | 0.366 |       0.727        |    0.638    |     0.661     | 0.706 | 0.693 |  0.682  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 14 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0079, Lr: 0.00041, Time: 1.47, Train Loss: 0.345, Valid Loss: 0.791
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.670 | 0.344 |       0.719        |    0.624    |     0.643     | 0.702 | 0.679 |  0.671  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 15 out of 100
#
# [ INFO ] 1 Fold, Epoch: 0080, Lr: 0.00018, Time: 1.44, Train Loss: 0.327, Valid Loss: 0.812
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# ...
# | 0.689 | 0.378 |       0.721        |    0.657    |     0.677     | 0.701 | 0.698 |  0.689  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 74 out of 100
#
# [ INFO ] 5 Fold, Epoch: 0147, Lr: 0.00473, Time: 1.59, Train Loss: 0.196, Valid Loss: 1.113
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.650 | 0.294 |       0.642        |    0.664    |     0.772     | 0.511 | 0.701 |  0.653  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 75 out of 100
#
# [ INFO ] 5 Fold, Epoch: 0148, Lr: 0.00458, Time: 1.55, Train Loss: 0.200, Valid Loss: 1.013
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.724 | 0.457 |       0.784        |    0.675    |     0.665     | 0.791 | 0.719 |  0.729  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 76 out of 100
#
# [ INFO ] 5 Fold, Epoch: 0149, Lr: 0.00434, Time: 1.58, Train Loss: 0.202, Valid Loss: 0.996
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.678 | 0.352 |       0.679        |    0.678    |     0.750     | 0.597 | 0.713 |  0.678  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 77 out of 100
#
# [ INFO ] 5 Fold, Epoch: 0150, Lr: 0.00401, Time: 1.52, Train Loss: 0.234, Valid Loss: 0.888
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.695 | 0.389 |       0.717        |    0.671    |     0.706     | 0.683 | 0.711 |  0.694  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 78 out of 100
#
# [ INFO ] 5 Fold, Epoch: 0151, Lr: 0.00361, Time: 1.51, Train Loss: 0.234, Valid Loss: 0.869
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.710 | 0.419 |       0.732        |    0.687    |     0.718     | 0.701 | 0.725 |  0.709  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 79 out of 100
#
# [ INFO ] 5 Fold, Epoch: 0152, Lr: 0.00317, Time: 1.48, Train Loss: 0.208, Valid Loss: 1.082
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.658 | 0.311 |       0.651        |    0.671    |     0.772     | 0.529 | 0.706 |  0.661  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 80 out of 100
#
# [ INFO ] 5 Fold, Epoch: 0153, Lr: 0.00269, Time: 1.52, Train Loss: 0.170, Valid Loss: 1.060
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.663 | 0.321 |       0.665        |    0.661    |     0.741     | 0.576 | 0.701 |  0.663  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 81 out of 100
#
# [ INFO ] 5 Fold, Epoch: 0154, Lr: 0.00220, Time: 1.55, Train Loss: 0.163, Valid Loss: 1.022
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.707 | 0.413 |       0.732        |    0.681    |     0.709     | 0.705 | 0.720 |  0.706  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 82 out of 100
#
# [ INFO ] 5 Fold, Epoch: 0155, Lr: 0.00172, Time: 1.56, Train Loss: 0.138, Valid Loss: 1.094
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.692 | 0.382 |       0.714        |    0.668    |     0.703     | 0.680 | 0.708 |  0.691  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 83 out of 100
#
# [ INFO ] 5 Fold, Epoch: 0156, Lr: 0.00127, Time: 1.52, Train Loss: 0.114, Valid Loss: 1.137
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.687 | 0.369 |       0.695        |    0.677    |     0.734     | 0.633 | 0.714 |  0.686  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 84 out of 100
#
# [ INFO ] 5 Fold, Epoch: 0157, Lr: 0.00087, Time: 1.50, Train Loss: 0.108, Valid Loss: 1.132
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.689 | 0.372 |       0.692        |    0.684    |     0.747     | 0.622 | 0.718 |  0.688  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 85 out of 100
#
# [ INFO ] 5 Fold, Epoch: 0158, Lr: 0.00055, Time: 1.45, Train Loss: 0.096, Valid Loss: 1.172
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.680 | 0.356 |       0.691        |    0.667    |     0.722     | 0.633 | 0.706 |  0.679  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 86 out of 100
#
# [ INFO ] 5 Fold, Epoch: 0159, Lr: 0.00030, Time: 1.43, Train Loss: 0.103, Valid Loss: 1.174
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.687 | 0.369 |       0.695        |    0.677    |     0.734     | 0.633 | 0.714 |  0.686  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 87 out of 100
#
# [ INFO ] 5 Fold, Epoch: 0160, Lr: 0.00015, Time: 1.53, Train Loss: 0.091, Valid Loss: 1.191
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.687 | 0.370 |       0.698        |    0.673    |     0.725     | 0.644 | 0.711 |  0.686  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 88 out of 100
#
# [ INFO ] 5 Fold, Epoch: 0161, Lr: 0.00010, Time: 1.58, Train Loss: 0.089, Valid Loss: 1.138
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.680 | 0.356 |       0.690        |    0.668    |     0.725     | 0.629 | 0.707 |  0.679  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 89 out of 100
#
# [ INFO ] 5 Fold, Epoch: 0162, Lr: 0.00094, Time: 1.48, Train Loss: 0.096, Valid Loss: 1.204
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.677 | 0.350 |       0.690        |    0.660    |     0.712     | 0.637 | 0.701 |  0.675  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 90 out of 100
#
# [ INFO ] 5 Fold, Epoch: 0163, Lr: 0.00178, Time: 1.53, Train Loss: 0.095, Valid Loss: 1.265
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.690 | 0.378 |       0.709        |    0.669    |     0.709     | 0.669 | 0.709 |  0.689  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 91 out of 100
#
# [ INFO ] 5 Fold, Epoch: 0164, Lr: 0.00262, Time: 1.53, Train Loss: 0.110, Valid Loss: 1.274
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.692 | 0.382 |       0.712        |    0.669    |     0.706     | 0.676 | 0.709 |  0.691  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 92 out of 100
#
# [ INFO ] 5 Fold, Epoch: 0165, Lr: 0.00346, Time: 1.55, Train Loss: 0.126, Valid Loss: 1.248
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.673 | 0.346 |       0.702        |    0.644    |     0.671     | 0.676 | 0.686 |  0.673  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 93 out of 100
#
# [ INFO ] 5 Fold, Epoch: 0166, Lr: 0.00430, Time: 1.49, Train Loss: 0.215, Valid Loss: 1.060
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.678 | 0.357 |       0.709        |    0.647    |     0.671     | 0.687 | 0.689 |  0.678  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 94 out of 100
#
# [ INFO ] 5 Fold, Epoch: 0167, Lr: 0.00426, Time: 1.46, Train Loss: 0.206, Valid Loss: 0.962
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.662 | 0.318 |       0.665        |    0.657    |     0.734     | 0.579 | 0.698 |  0.661  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 95 out of 100
#
# [ INFO ] 5 Fold, Epoch: 0168, Lr: 0.00412, Time: 1.42, Train Loss: 0.194, Valid Loss: 1.027
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.704 | 0.407 |       0.730        |    0.676    |     0.703     | 0.705 | 0.716 |  0.703  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 96 out of 100
#
# [ INFO ] 5 Fold, Epoch: 0169, Lr: 0.00390, Time: 1.47, Train Loss: 0.203, Valid Loss: 1.011
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.694 | 0.384 |       0.708        |    0.676    |     0.722     | 0.662 | 0.715 |  0.692  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 97 out of 100
#
# [ INFO ] 5 Fold, Epoch: 0170, Lr: 0.00361, Time: 1.47, Train Loss: 0.163, Valid Loss: 1.060
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.699 | 0.394 |       0.713        |    0.681    |     0.725     | 0.669 | 0.719 |  0.697  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 98 out of 100
#
# [ INFO ] 5 Fold, Epoch: 0171, Lr: 0.00325, Time: 1.50, Train Loss: 0.185, Valid Loss: 0.997
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.700 | 0.398 |       0.720        |    0.679    |     0.715     | 0.683 | 0.717 |  0.699  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 99 out of 100
#
# [ INFO ] 5 Fold, Epoch: 0172, Lr: 0.00285, Time: 1.55, Train Loss: 0.172, Valid Loss: 1.026
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.709 | 0.418 |       0.738        |    0.679    |     0.703     | 0.716 | 0.720 |  0.708  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# EarlyStopping counter: 100 out of 100
# 42 done

# %%
oof_preds_tensor = torch.as_tensor( oof_preds_list )
oof_trues_tensor = torch.as_tensor( oof_trues_list )
# Out:
# /tmp/ipykernel_50635/139030946.py:1: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:245.)
#   oof_preds_tensor = torch.as_tensor( oof_preds_list )

# %%
analysis_table( analysis( oof_preds_tensor.view(-1), oof_trues_tensor.view(-1)) )
# Out:
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.819 | 0.606 |       0.860        |    0.745    |     0.859     | 0.747 | 0.860 |  0.864  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+

# %%
oof_preds_tensor_binary = torch.where( oof_preds_tensor > 0.5, 1, 0 ).float()
oof_trues_tensor_binary = torch.where( oof_trues_tensor > 0.5, 1, 0 ).float()

# %%
oof_preds_mean = oof_preds_tensor_binary.mean(dim=0)
oof_trues_mean = oof_trues_tensor_binary.mean(dim=0)

# %%
analysis_table( analysis( oof_preds_mean, oof_trues_mean ) )
# Out:
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC  | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.819 | 0.606 |       0.860        |    0.745    |     0.859     | 0.747 | 0.860 |  0.803  |
# +-------+-------+--------------------+-------------+---------------+-------+-------+---------+

# %%
def inference( dataset, model_paths, grid ):
    print(f"How Many Models?: {len(model_paths)}")
    loader = GraphDataLoader(dataset, batch_size=512, shuffle=False, drop_last=False)
    preds = []
    trues = []
    names = []
    for idx, model_dict in enumerate(model_paths):
        model.load_state_dict( torch.load( model_dict )['model_state_dict'] )
        loss, pred, true, name = valid_model( model, loader, device=device ) ## 1 fold 

        preds.append(pred)
        trues.append(true)
        
        if idx == 0:
            names.append(name)
            
    preds = torch.as_tensor(preds)
    trues = torch.as_tensor(trues)

    preds = torch.where( preds >= grid, 1, 0 ).float()
    preds = preds.mean(dim=0)
    trues = torch.where( trues >= grid, 1, 0 ).float()
    trues = trues.mean(dim=0)
    
    return preds, trues, names

# %%
model = MetabolicStabilityPrediction(hyperparameter['node_dim'], hyperparameter['out_size'], hyperparameter['edge_dim'], hyperparameter['pose_dim'], hyperparameter['num_layers']).to(device)
test  = MSPDataset(  sorted(glob("./data/CMMS-GCL/test/*")),  pos_dim=20 )

test_pred, test_true, test_name = inference( test, glob( f'./save/seed42/*/*' ), 0.5)
analysis_table( analysis( test_pred, test_true ) )
# Out:
# How Many Models?: 10
# +-------+--------+--------------------+-------------+---------------+-------+-------+---------+
# |  ACC  |  MCC   | Sensitivity Recall | Specificity | Precision PPV |  NPV  |   F1  | ROC_AUC |
# +-------+--------+--------------------+-------------+---------------+-------+-------+---------+
# | 0.649 | -0.012 |       0.817        |    0.172    |     0.736     | 0.250 | 0.775 |  0.530  |
# +-------+--------+--------------------+-------------+---------------+-------+-------+---------+

# %%
test_pred3
# Out:
# tensor([0.9000, 0.9000, 1.0000, 1.0000, 1.0000, 1.0000, 0.9000, 1.0000, 1.0000,
#         1.0000, 0.9000, 0.9000, 0.9000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000,
#         0.9000, 1.0000, 1.0000, 1.0000, 1.0000, 0.4000, 1.0000, 0.9000, 0.9000,
#         0.8000, 0.0000, 0.9000, 0.0000, 0.0000, 0.1000, 1.0000, 0.6000, 0.0000,
#         0.1000, 0.1000, 0.9000, 1.0000, 1.0000, 0.8000, 0.4000, 0.9000, 1.0000,
#         1.0000, 0.1000, 1.0000, 1.0000, 0.8000, 1.0000, 1.0000, 0.5000, 1.0000,
#         1.0000, 0.6000, 0.9000, 1.0000, 0.6000, 0.9000, 1.0000, 1.0000, 1.0000,
#         0.7000, 0.7000, 1.0000, 0.2000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000,
#         1.0000, 1.0000, 0.0000, 1.0000, 1.0000, 0.2000, 1.0000, 0.2000, 0.8000,
#         1.0000, 0.2000, 0.7000, 0.1000, 0.1000, 1.0000, 0.8000, 0.5000, 1.0000,
#         1.0000, 0.1000, 0.9000, 0.9000, 1.0000, 0.9000, 1.0000, 1.0000, 1.0000,
#         1.0000, 0.9000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 0.8000, 1.0000,
#         1.0000, 1.0000, 1.0000])
